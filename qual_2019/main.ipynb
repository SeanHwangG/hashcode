# %%
# %load_ext autoreload
# %autoreload 2

from importlib import reload
import typing
from typing import List

from slide import Slide
from image import Image
from slide_show import SlideShow
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
images = Image.read_input("d_pet_pictures.txt")

# %%
slides = Slide.combine_images(images, mode="uncombined")
dataframe = Slide.to_df(slides)
# Out:
# 2021-02-14 21:30:40,897, INFO     [slide.py:70] 90000

# %%
dataframe.hist()
# Out:
# array([[<AxesSubplot:title={'center':'t86'}>,
#         <AxesSubplot:title={'center':'ts2'}>,
#         <AxesSubplot:title={'center':'td4'}>,
#         <AxesSubplot:title={'center':'tf1'}>,
#         <AxesSubplot:title={'center':'tc5'}>,
#         <AxesSubplot:title={'center':'tl5'}>,
#         <AxesSubplot:title={'center':'tw3'}>,
#         <AxesSubplot:title={'center':'tc4'}>,
#         <AxesSubplot:title={'center':'t6'}>,
#         <AxesSubplot:title={'center':'tm2'}>,
#         <AxesSubplot:title={'center':'th5'}>,
#         <AxesSubplot:title={'center':'tl2'}>,
#         <AxesSubplot:title={'center':'t44'}>,
#         <AxesSubplot:title={'center':'t52'}>,
#         <AxesSubplot:title={'center':'t82'}>],
#        [<AxesSubplot:title={'center':'t47'}>,
#         <AxesSubplot:title={'center':'t42'}>,
#         <AxesSubplot:title={'center':'t87'}>,
#         <AxesSubplot:title={'center':'tx4'}>,
#         <AxesSubplot:title={'center':'tp6'}>,
# ...
